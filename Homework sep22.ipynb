# %%
s = "Roshni Sahani"

print(s)
# Out:
# Roshni Sahani

# %%
s = "Roshni Sahani"

char1 =s[0]
char2 =s[1]
char3 =s[2]
char4 =s[3]
char5 =s[4]
char6 =s[5]
char7 =s[6]
char8 =s[7]
char9 =s[8]
char10 =s[9]
char11 =s[10]
char12 =s[11]
char13=s[12]


print(char1,char2,char3,char4,char5,char6)
print(char7,char8,char9,char10,char11,char12,char13)
# Out:
# R o s h n i
#   S a h a n i

# %%
s = "Roshni Sahani"

char1 =s[-1]
char2 =s[-2]
char3 =s[-3]
char4 =s[-4]
char5 =s[-5]
char6 =s[-6]
char7 =s[-7]
char8 =s[-8]
char9 =s[-9]
char10 =s[-10]
char11 =s[-11]
char12 =s[-12]
char13=s[-13]


print(char1,char2,char3,char4,char5,char6)
print(char7,char8,char9,char10,char11,char12,char13)
# Out:
# i n a h a S
#   i n h s o R

# %%
s ="Roshni Sahani"

char1 =s[0]
char2 =s[-6]

print(char1,char2)
# Out:
# R S

# %%
s ="Roshni Sahani"

char1 =s[-6]
char2 =s[0]

print(char1,char2)
# Out:
# S R

# %%
s ="Roshni Sahani"

char1 =s[0]
char2 =s[1]
char3 =s[2]
char4 =s[3]
char5 =s[4]
char6 =s[5]

print(char1)
print(char2)
print(char3)
print(char4)
print(char5)
print(char6)
# Out:
# R
# o
# s
# h
# n
# i

# %%
s ="Roshni Sahani"

char1 =s[-7]
char2 =s[-8]
char3 =s[-9]
char4 =s[-10]
char5 =s[-11]
char6 =s[-12]
char7 =s[-13]

print(char1)
print(char2)
print(char3)
print(char4)
print(char5)
print(char6)
print(char7)
# Out:
#
# i
# n
# h
# s
# o
# R

# %%
s ="Roshni Sahani"

char1 =s[-7]
char2 =s[-8]
char3 =s[-9]
char4 =s[-10]
char5 =s[-11]
char6 =s[-12]
char7 =s[-13]

print(char1,char2,char3,char4,char5,char6,char7)
# Out:
#   i n h s o R

# %%
s ="Roshni Sahani"

char1 =s[-13]
char2 =s[-12]
char3 =s[-11]
char4 =s[-10]
char5 =s[0]
char6 =s[1]
char7 =s[2]
char8 =s[3]

print(char4,char3,char2,char1)
print(char5,char6,char7,char8)
# Out:
# h s o R
# R o s h
