# %%
s = "Roshni Sahani"

print(s[0:13])
# Out:
# Roshni Sahani

# %%
s ="Roshni Sahani"

print(s[::-1])
# Out:
# inahaS inhsoR

# %%
s ="Roshni Sahani"

print(s[5::-1],s[12:6:-1])
# Out:
# inhsoR inahaS

# %%
s = "Roshni Sahani"

print(s[0:4])
# Out:
# Rosh

# %%
 s = "Roshni Sahani"

 print(s[3::-1])
# Out:
# hsoR

# %%
s = "Roshni Sahani"

print(s[0:1])
print(s[0:2])
print(s[0:3])
print(s[0:4])
print(s[0:5])
print(s[0:6])
# Out:
# R
# Ro
# Ros
# Rosh
# Roshn
# Roshni

# %%
s ="Roshni Sahani"

print(s[0:1],s[2:3],s[4:5],s[5:6])
# Out:
# R s n i

# %%
s ="Roshni Sahani"

print(s[5:3:-1],s[2:0:-1],s[0:1])
# Out:
# in so R

# %%
s ="Roshni Sahani"

print(s[5:4:-1],s[4:3:-1] ,s[2:1:-1],s[0:1])
# Out:
# i n s R

# %%
s ="Roshni Sahani"

print(s[2:3],s[3:4],s[4:5],s[5:6])
# Out:
# s h n i

# %%
s ="Roshni Sahani"

print(s[5:4:-1],s[4:3:-1],s[3:2:-1],s[2:1:-1])
# Out:
# i n h s

# %%
s ="Roshni Sahani"

print(s[7:11])
# Out:
# Saha

# %%
s ="Roshni Sahani"

print(s[4:6])
# Out:
# ni

# %%
s ="Roshni Sahani"

print(s[5:1:-1])
# Out:
# inhs

# %%
s ="Roshni Sahani"

print(s[2:6])
# Out:
# shni

# %%
s ="Roshni Sahani"

print(s[4:1:-1])
# Out:
# nhs

# %%
s ="Roshni Sahani"

print(s[7:10])
# Out:
# Sah
